# %% [markdown]
# # Intuition on AAPD
#
# This notebook contains the exploratory data analysis of the provided Arxiv dataset.
#
# - Q1: is the dataset the same as the one hosted in HF? A: yes, use this for loading the dataset
# - Q2: what knowledge can we gain on the *categories* for subsequent use in training performant models? A: hierarchical labelset; not human-readable labels; exploit category distribution to make balanced validation split
#   - Q3: what is the distribution of the number of papers per category? A: plot1.1
#   - Q4: what is the distribution of the number of categories per paper? A: Label cardinality: 1.6957565665834098
#   - Q5: is there any label noise or inconsistency? A: hard to know, could use a package such as [cleanlab](https://github.com/cleanlab/cleanlab) to estimate label noise
#     - Q6: how many papers are in more than one category? A: by checking title if they are unique? 4020 papers with non-unique titles
#   - Q7: is there a long-tail of primary-secondary categories? A: plot1.3
# - Q7:
#   - Q8: what is the distribution of the number of words per *abstract*? A: plot2.1
#   - Q9: are all abstracts/papers in English? A: predominantly English, used [langdetect](https://pypi.org/project/langdetect/) to detect the language of the abstracts
# Q10: Given primary categories/fields is the data somewhat separable? A: plot 3.1: PCA of sentence embeddings per unique category
#
# #### nice documentation
# https://www.kaggle.com/code/matthewmaddock/nlp-arxiv-dataset-transformers-and-umap

# %%
# %load_ext autoreload
# %autoreload 2
## necessary installs for EDA
# !pip3 install numpy
# !pip3 install scipy
# !pip3 install beautifulsoup4
# !pip3 install scikit-learn
# !pip3 install matplotlib
# !pip3 install pandas
# !pip3 install plotly
# !pip3 install datasets #hf datasets contains the dataset loader
# !pip3 install sentence-transformers #for sentence embeddings EDA on abstracts
# Out:
# Requirement already satisfied: numpy in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (1.21.1)
# WARNING: You are using pip version 21.0.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/home/jordy/.virtualenvs/SOTA/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: scipy in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (1.10.0)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from scipy) (1.21.1)
# WARNING: You are using pip version 21.0.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/home/jordy/.virtualenvs/SOTA/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: beautifulsoup4 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from beautifulsoup4) (2.3.2.post1)
# WARNING: You are using pip version 21.0.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/home/jordy/.virtualenvs/SOTA/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: scikit-learn in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from scikit-learn) (1.21.1)
# Requirement already satisfied: scipy>=0.19.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from scikit-learn) (1.0.1)
# WARNING: You are using pip version 21.0.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/home/jordy/.virtualenvs/SOTA/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (3.7.1)
# Requirement already satisfied: numpy>=1.20 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (1.21.1)
# Requirement already satisfied: cycler>=0.10 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (5.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: six in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# WARNING: You are using pip version 21.0.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/home/jordy/.virtualenvs/SOTA/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from pandas) (1.21.1)
# Requirement already satisfied: pytz>=2017.3 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: You are using pip version 21.0.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/home/jordy/.virtualenvs/SOTA/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: plotly in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (5.13.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from plotly) (8.2.2)
# WARNING: You are using pip version 21.0.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/home/jordy/.virtualenvs/SOTA/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: datasets in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (2.14.5)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: numpy>=1.17 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (1.21.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (13.0.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (0.17.3)
# Requirement already satisfied: tqdm>=4.62.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (4.64.0)
# Requirement already satisfied: requests>=2.19.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (2.28.2)
# Requirement already satisfied: multiprocess in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: pandas in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (1.2.4)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (0.3.4)
# Requirement already satisfied: xxhash in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: aiohttp in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (3.8.1)
# Requirement already satisfied: packaging in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from datasets) (6.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from aiohttp->datasets) (20.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.8.0)
# Requirement already satisfied: filelock in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2022.5.18.1)
# Requirement already satisfied: pytz>=2017.3 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# WARNING: You are using pip version 21.0.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/home/jordy/.virtualenvs/SOTA/bin/python -m pip install --upgrade pip' command.
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from sentence-transformers) (1.21.1)
# Collecting transformers<5.0.0,>=4.32.0
#   Downloading transformers-4.37.2-py3-none-any.whl (8.4 MB)
#      |████████████████████████████████| 8.4 MB 7.4 MB/s eta 0:00:01
# Requirement already satisfied: torch>=1.11.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from sentence-transformers) (1.12.1+cu113)
# Requirement already satisfied: sentencepiece in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from sentence-transformers) (0.1.95)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from sentence-transformers) (0.17.3)
# Requirement already satisfied: scipy in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: Pillow in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: tqdm in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: scikit-learn in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from sentence-transformers) (0.24.2)
# Requirement already satisfied: nltk in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: packaging>=20.9 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.0)
# Requirement already satisfied: requests in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.28.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.8.0)
# Requirement already satisfied: fsspec in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Collecting huggingface-hub>=0.15.1
#   Downloading huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
#      |████████████████████████████████| 330 kB 6.4 MB/s eta 0:00:01
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 7.0 MB/s eta 0:00:01
# Collecting tokenizers<0.19,>=0.14
#   Downloading tokenizers-0.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 6.9 MB/s eta 0:00:01
# Requirement already satisfied: regex!=2019.12.17 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: click in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from nltk->sentence-transformers) (1.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.12)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages (from scikit-learn->sentence-transformers) (2.1.0)
# Installing collected packages: huggingface-hub, tokenizers, safetensors, transformers, sentence-transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.12.1
#     Uninstalling tokenizers-0.12.1:
#       Successfully uninstalled tokenizers-0.12.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.28.0.dev0
#     Uninstalling transformers-4.28.0.dev0:
#       Successfully uninstalled transformers-4.28.0.dev0
# Successfully installed huggingface-hub-0.20.3 safetensors-0.4.2 sentence-transformers-2.3.1 tokenizers-0.15.1 transformers-4.37.2
# WARNING: You are using pip version 21.0.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/home/jordy/.virtualenvs/SOTA/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import plotly.graph_objects as go

# %%
from datasets import load_dataset
data = load_dataset("arxiv_dataset", data_dir='/home/jordy/code/opensource/IRIS/AAPD/data', ignore_verifications=True) #has to be a full path due to sloppy coding in hf datasets

## error: Nonmatchingsplitsize (patch HF dataset?) --> ignore_verifications
#NonMatchingSplitsSizesError: [{'expected': SplitInfo(name='train', num_bytes=3056873071, num_examples=2349354, shard_lengths=None, dataset_name=None), 'recorded': SplitInfo(name='train', num_bytes=3132619006, num_examples=2399802, shard_lengths=[415000, 385000, 367000, 350000, 343000, 401000, 138802], dataset_name='arxiv_dataset')}]
data
# Out:
# /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages/datasets/load.py:2097: FutureWarning: 'ignore_verifications' was deprecated in favor of 'verification_mode' in version 2.9.1 and will be removed in 3.0.0.
# You can remove this warning by passing 'verification_mode=no_checks' instead.
#   warnings.warn(
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'submitter', 'authors', 'title', 'comments', 'journal-ref', 'doi', 'report-no', 'categories', 'license', 'abstract', 'update_date'],
#         num_rows: 2399802
#     })
# })

# %%
data['train']['categories'] #is organized according to primary and secondary categories; each category seems to be a hierarchical label (e.g. cs.AI is a subcategory of cs)
# data['train']['abstract'] #abstracts are not tokenized
# Out:
# ['hep-ph',
#  'math.CO cs.CG',
#  'physics.gen-ph',
#  'math.CO',
#  'math.CA math.FA',
#  'cond-mat.mes-hall',
#  'gr-qc',
#  'cond-mat.mtrl-sci',
#  'astro-ph',
#  'math.CO',
#  'math.NT math.AG',
#  'math.NT',
#  'math.NT',
#  'math.CA math.AT',
#  'hep-th',
#  'hep-ph',
#  'astro-ph',
#  'hep-th',
#  'math.PR math.AG',
#  'hep-ex',
#  'nlin.PS physics.chem-ph q-bio.MN',
#  'math.NA',
#  'astro-ph',
#  'nlin.PS',
#  'cond-mat.str-el cond-mat.stat-mech',
#  'math.RA',
#  'cond-mat.mes-hall',
#  'math.CA math.PR',
#  'hep-ph',
#  'cond-mat.str-el',
#  'hep-ph',
#  'hep-ph',
#  'physics.optics physics.comp-ph',
#  'q-bio.PE q-bio.CB quant-ph',
#  'physics.optics physics.comp-ph',
#  'q-bio.QM q-bio.MN',
#  'physics.optics physics.comp-ph',
#  'physics.optics physics.comp-ph',
#  'hep-ph hep-lat nucl-th',
#  'math.OA math.FA',
#  'math.QA math-ph math.MP',
#  'physics.gen-ph quant-ph',
#  'cond-mat.stat-mech cond-mat.mtrl-sci',
#  'astro-ph nlin.CD physics.plasm-ph physics.space-ph',
#  'nlin.PS nlin.SI',
#  'quant-ph cs.IT math.IT',
#  'cs.NE cs.AI',
#  'gr-qc astro-ph',
#  'math.CO',
#  'cs.NE cs.AI',
#  'physics.ed-ph quant-ph',
#  'hep-th',
#  'math.DG gr-qc',
#  'math.CA math.FA',
#  'cond-mat.soft cond-mat.mtrl-sci',
#  'cond-mat.soft cond-mat.mtrl-sci',
#  'cond-mat.str-el',
#  'physics.pop-ph',
#  'astro-ph',
#  'nucl-th',
#  'math.FA',
#  'cs.DS',
#  'hep-ph',
#  'hep-th',
#  'math.AG math.CO',
#  'hep-th',
#  'cond-mat.mtrl-sci',
#  'math.NT math.CV',
#  'math.DS',
#  'cond-mat.mes-hall',
#  'physics.soc-ph',
#  'math-ph math.MP',
#  'math.AG',
#  'math.RA',
#  'hep-ph hep-ex nucl-ex',
#  'hep-ph hep-ex',
#  'physics.gen-ph',
#  'gr-qc',
#  'math.OA',
#  'astro-ph',
#  'math.QA hep-th math-ph math.MP math.RT',
#  'cond-mat.other cond-mat.stat-mech',
#  'hep-th',
#  'cond-mat.soft nlin.PS physics.flu-dyn',
#  'hep-th',
#  'math.PR',
#  'math.DG',
#  'physics.optics',
#  'physics.data-an physics.gen-ph',
#  'cs.CE cond-mat.stat-mech cs.MS cs.NA physics.data-an',
#  'math.GR',
#  'hep-lat hep-ph',
#  'cond-mat.supr-con cond-mat.str-el',
#  'astro-ph',
#  'math.GR math.DG',
#  'nlin.SI',
#  'math-ph math.MP math.OA',
#  'cs.IT math.IT',
#  'math.FA',
#  'gr-qc',
#  'hep-th',
#  'math.AC math.AG',
#  'gr-qc',
#  'math.DG math.RT',
#  'math.SG',
#  'hep-ph nucl-th',
#  'physics.data-an',
#  'cs.CC',
#  'cond-mat.mtrl-sci cond-mat.other',
#  'math.OA',
#  'math.QA math.KT',
#  'math.RA',
#  'cond-mat.mtrl-sci',
#  'cond-mat.str-el',
#  'math.GT',
#  'math-ph hep-th math.MP',
#  'quant-ph',
#  'cond-mat.supr-con cond-mat.mtrl-sci',
#  'cond-mat.str-el',
#  'hep-ex hep-ph',
#  'hep-th',
#  'cond-mat.other',
#  'nlin.CD cond-mat.other physics.optics',
#  'math.CV',
#  'math.AP',
#  'cond-mat.supr-con',
#  'cond-mat.mtrl-sci',
#  'astro-ph',
#  'math.DS math-ph math.AP math.MP',
#  'math.RT',
#  'physics.gen-ph',
#  'cond-mat.mes-hall',
#  'astro-ph',
#  'nucl-th',
#  'quant-ph',
#  'physics.gen-ph',
#  'quant-ph',
#  'gr-qc astro-ph',
#  'astro-ph',
#  'hep-th',
#  'hep-ph',
#  'cond-mat.stat-mech',
#  'hep-ph',
#  'hep-th astro-ph gr-qc',
#  'gr-qc',
#  'cond-mat.other',
#  'physics.optics physics.class-ph quant-ph',
#  'cond-mat.mtrl-sci',
#  'gr-qc',
#  'cond-mat.str-el',
#  'physics.data-an physics.comp-ph',
#  'nucl-th',
#  'physics.gen-ph',
#  'nucl-th hep-ph nucl-ex',
#  'astro-ph',
#  'astro-ph',
#  'cond-mat.stat-mech cond-mat.soft physics.chem-ph',
#  'q-bio.OT',
#  'cond-mat.str-el cond-mat.soft',
#  'astro-ph',
#  'cond-mat.mtrl-sci',
#  'physics.data-an physics.comp-ph',
#  'cond-mat.mtrl-sci',
#  'math.GT',
#  'math.QA math.RT',
#  'hep-th',
#  'hep-ph',
#  'astro-ph',
#  'hep-ph',
#  'cond-mat.str-el cond-mat.mtrl-sci',
#  'astro-ph',
#  'cond-mat.mes-hall cond-mat.str-el',
#  'cond-mat.mtrl-sci',
#  'hep-ph hep-ex',
#  'astro-ph gr-qc hep-th',
#  'cond-mat.other cond-mat.mtrl-sci',
#  'physics.optics',
#  'physics.plasm-ph',
#  'quant-ph',
#  'nucl-th',
#  'physics.optics physics.comp-ph',
#  'cond-mat.mtrl-sci',
#  'cond-mat.mtrl-sci',
#  'astro-ph',
#  'cond-mat.mtrl-sci',
#  'hep-ph',
#  'astro-ph',
#  'cond-mat.other',
#  'math.GR',
#  'hep-ex astro-ph hep-ph',
#  'physics.bio-ph physics.data-an q-bio.BM',
#  'astro-ph',
#  'cond-mat.mtrl-sci cond-mat.stat-mech',
#  'cond-mat.mes-hall quant-ph',
#  'math.QA math.RT',
#  'hep-ph',
#  'nlin.CG',
#  'cond-mat.str-el cond-mat.other',
#  'math.CO math.GR',
#  'hep-ph nucl-ex',
#  'math.RT math.QA',
#  'quant-ph',
#  'astro-ph',
#  'cond-mat.supr-con cond-mat.mes-hall',
#  'astro-ph',
#  'physics.optics',
#  'astro-ph gr-qc nucl-th',
#  'math.GT math.QA',
#  'astro-ph',
#  'math.DG',
#  'math.CO',
#  'hep-th astro-ph gr-qc',
#  'cs.CC',
#  'quant-ph hep-th',
#  'math.PR',
#  'cond-mat.mtrl-sci',
#  'cs.IT math.IT',
#  'cs.DM cs.LO',
#  'astro-ph',
#  'nucl-ex',
#  'astro-ph gr-qc hep-ph hep-th',
#  'astro-ph',
#  'astro-ph',
#  'nucl-ex',
#  'astro-ph',
#  'astro-ph',
#  'nucl-ex',
#  'gr-qc astro-ph quant-ph',
#  'cs.CC',
#  'astro-ph',
#  'math.CV',
#  'hep-th',
#  'cond-mat.other',
#  'astro-ph',
#  'hep-ph hep-ex',
#  'math.DG',
#  'astro-ph',
#  'astro-ph',
#  'cond-mat.soft',
#  'hep-th',
#  'cond-mat.supr-con',
#  'astro-ph',
#  'cond-mat.str-el',
#  'cond-mat.mtrl-sci',
#  'hep-th hep-ph',
#  'cond-mat.mes-hall',
#  'hep-th gr-qc',
#  'physics.optics math-ph math.MP',
#  'cond-mat.str-el',
#  'cond-mat.str-el cond-mat.dis-nn',
#  'quant-ph',
#  'hep-ph',
#  'astro-ph',
#  'hep-ph',
#  'astro-ph',
#  'astro-ph',
#  'math.SG math.AG',
#  'hep-th cond-mat.stat-mech',
#  'astro-ph',
#  'math.FA math.AP',
#  'astro-ph',
#  'hep-th',
#  'physics.flu-dyn physics.plasm-ph',
#  'hep-ph hep-th nucl-th',
#  'astro-ph',
#  'astro-ph',
#  'astro-ph',
#  'quant-ph',
#  'astro-ph',
#  'astro-ph',
#  'cond-mat.stat-mech q-bio.PE',
#  'astro-ph',
#  'math-ph math.GT math.MP',
#  'physics.comp-ph',
#  'math.MG',
#  'astro-ph',
#  'math.CO',
#  'gr-qc',
#  'astro-ph',
#  'astro-ph',
#  'astro-ph',
#  'cs.IT cs.CC math.IT',
#  'math.QA',
#  'hep-th gr-qc',
#  'cond-mat.mes-hall cond-mat.mtrl-sci',
#  'math.AP math-ph math.MP',
#  'astro-ph',
#  'nucl-th',
#  'cond-mat.mes-hall',
#  'astro-ph',
#  'physics.atom-ph cond-mat.other',
#  'hep-ph',
#  'hep-ph',
#  'hep-ph',
#  'math.CO math.GT',
#  'hep-th',
#  'astro-ph',
#  'math.FA math.SP',
#  'hep-th astro-ph gr-qc',
#  'cond-mat.mes-hall cond-mat.mtrl-sci',
#  'cs.CC',
#  'math.ST stat.TH',
#  'astro-ph physics.ao-ph',
#  'cs.IT cs.AI math.IT q-bio.PE',
#  'physics.bio-ph',
#  'nucl-ex hep-ex',
#  'astro-ph',
#  'physics.soc-ph',
#  'cs.CC cs.DM',
#  'astro-ph',
#  'cond-mat.mes-hall cond-mat.mtrl-sci',
#  'astro-ph',
#  'cond-mat.str-el',
#  'hep-ph astro-ph hep-th',
#  'math.PR math.AP',
#  'astro-ph',
#  'math.DG',
#  'nucl-th hep-ph',
#  'cond-mat.mes-hall',
#  'cond-mat.stat-mech',
#  'cond-mat.str-el cond-mat.mtrl-sci',
#  'nlin.PS nlin.CD q-bio.PE',
#  'quant-ph',
#  'math.AP',
#  'cond-mat.stat-mech physics.ins-det',
#  'math.ST cond-mat.stat-mech stat.TH',
#  'cond-mat.str-el cond-mat.mtrl-sci',
#  'hep-ph',
#  'math.PR math.CA math.ST stat.TH',
#  'hep-ph',
#  'q-bio.OT',
#  'gr-qc',
#  'cond-mat.str-el',
#  'physics.chem-ph',
#  'math.PR q-fin.CP q-fin.PR',
#  'cond-mat.mes-hall',
#  'math.AP',
#  'cond-mat.mtrl-sci',
#  'physics.flu-dyn physics.comp-ph',
#  'quant-ph',
#  'hep-ph',
#  'math.AT',
#  'cond-mat.soft cond-mat.dis-nn',
#  'astro-ph',
#  'physics.soc-ph',
#  'astro-ph',
#  'math.AP math.CA',
#  'astro-ph',
#  'math.CO math.MG',
#  'astro-ph',
#  'astro-ph',
#  'cond-mat.soft cond-mat.supr-con',
#  'nucl-th quant-ph',
#  'hep-th gr-qc',
#  'astro-ph',
#  'astro-ph',
#  'q-bio.PE q-bio.OT',
#  'hep-ph',
#  'math.CV',
#  'astro-ph',
#  'cs.IT math.IT',
#  'math-ph hep-th math.MP',
#  'physics.gen-ph',
#  'hep-ex',
#  'cond-mat.supr-con cond-mat.str-el',
#  'gr-qc hep-th',
#  'gr-qc',
#  'cond-mat.str-el',
#  'hep-ph',
#  'cond-mat.mtrl-sci',
#  'gr-qc',
#  'quant-ph',
#  'quant-ph hep-th',
#  'physics.geo-ph',
#  'physics.chem-ph',
#  'quant-ph cond-mat.mes-hall',
#  'hep-ph hep-th nucl-th',
#  'math.CV math.CA',
#  'cond-mat.soft cond-mat.stat-mech',
#  'math.PR',
#  'astro-ph',
#  'math.NT',
#  'cond-mat.str-el',
#  'nucl-ex',
#  'cond-mat.other',
#  'quant-ph cond-mat.other',
#  'astro-ph',
#  'hep-ph',
#  'gr-qc',
#  'math.DS',
#  'cond-mat.mes-hall',
#  'q-bio.NC cond-mat.dis-nn physics.soc-ph',
#  'cond-mat.mtrl-sci',
#  'q-fin.RM math.PR',
#  'hep-ph',
#  'cond-mat.str-el',
#  'quant-ph',
#  'math.PR',
#  'gr-qc hep-th',
#  'nlin.SI cond-mat.stat-mech hep-th',
#  'astro-ph',
#  'math.AP',
#  'quant-ph',
#  'hep-ph hep-ex',
#  'math.PR',
#  'cond-mat.str-el cond-mat.supr-con',
#  'nucl-th',
#  'cond-mat.mes-hall',
#  'quant-ph hep-th nlin.CD physics.atom-ph physics.chem-ph',
#  'cond-mat.mes-hall',
#  'cond-mat.mes-hall cond-mat.mtrl-sci',
#  'math.RT math.RA',
#  'hep-ph',
#  'physics.optics',
#  'cond-mat.mes-hall',
#  'math.GT math.AG',
#  'math-ph math.MP',
#  'cond-mat.dis-nn quant-ph',
#  'cond-mat.supr-con',
#  'quant-ph',
#  'astro-ph',
#  'physics.optics',
#  'astro-ph',
#  'nucl-ex',
#  'hep-th',
#  'astro-ph',
#  'cond-mat.dis-nn cond-mat.stat-mech',
#  'astro-ph',
#  'q-bio.SC q-bio.CB',
#  'math.SG math.AG',
#  'gr-qc astro-ph.HE',
#  'math.QA',
#  'math-ph math.DG math.MP',
#  'physics.chem-ph physics.flu-dyn',
#  'gr-qc hep-th',
#  'physics.gen-ph',
#  'hep-ex hep-lat hep-ph',
#  'hep-ph',
#  'cond-mat.mes-hall',
#  'cond-mat.other hep-th quant-ph',
#  'astro-ph',
#  'physics.optics physics.gen-ph quant-ph',
#  'nucl-th nucl-ex',
#  'hep-th',
#  'hep-th',
#  'math.AG math.GR',
#  'cond-mat.mes-hall',
#  'astro-ph',
#  'hep-th',
#  'cond-mat.str-el',
#  'cond-mat.mes-hall',
#  'astro-ph',
#  'cond-mat.supr-con cond-mat.str-el',
#  'astro-ph',
#  'astro-ph',
#  'gr-qc',
#  'cond-mat.supr-con cond-mat.mes-hall quant-ph',
#  'astro-ph',
#  'math.CO',
#  'astro-ph',
#  'quant-ph',
#  'astro-ph',
#  'astro-ph',
#  'q-bio.BM',
#  'cond-mat.stat-mech cond-mat.other',
#  'cond-mat.supr-con cond-mat.str-el',
#  'astro-ph',
#  'cs.CC cs.DS',
#  'math.AG math.CO',
#  'astro-ph',
#  'nucl-ex nucl-th',
#  'cond-mat.stat-mech cond-mat.mtrl-sci cond-mat.soft',
#  'math.OC',
#  'cond-mat.mtrl-sci cond-mat.stat-mech',
#  'astro-ph',
#  'quant-ph',
#  'astro-ph',
#  'astro-ph',
#  'math.AG math.KT',
#  'cond-mat.mes-hall',
#  'nucl-th',
#  'quant-ph',
#  'cond-mat.supr-con',
#  'physics.ed-ph physics.gen-ph',
#  'math.OC',
#  'astro-ph',
#  'physics.gen-ph',
#  'gr-qc',
#  'quant-ph',
#  'hep-ph astro-ph hep-th',
#  'cond-mat.soft cond-mat.dis-nn',
#  'cs.CR',
#  'cond-mat.stat-mech cond-mat.soft',
#  'cond-mat.supr-con cond-mat.mtrl-sci',
#  'quant-ph math-ph math.MP',
#  'nucl-th',
#  'math.AP',
#  'hep-ex',
#  'cs.IT math.IT',
#  'math.GR',
#  'math.AP math-ph math.MP',
#  'math.AT math.CT',
#  'math.AT math.DG',
#  'nucl-th',
#  'hep-th gr-qc',
#  'cond-mat.str-el',
#  'hep-th quant-ph',
#  'math.PR',
#  'math.PR',
#  'hep-ph astro-ph',
#  'quant-ph math-ph math.MP',
#  'cond-mat.stat-mech',
#  'astro-ph',
#  'math.LO math.CO',
#  'cond-mat.mes-hall',
#  'quant-ph',
#  'math.ST stat.TH',
#  'astro-ph',
#  'math-ph math.MP',
#  'quant-ph cond-mat.other physics.atom-ph',
#  'cond-mat.str-el',
#  'hep-ex',
#  'quant-ph',
#  'math.PR',
#  'gr-qc',
#  'math-ph hep-th math.MP',
#  'hep-th',
#  'cs.NI cs.IT math.IT',
#  'cond-mat.supr-con',
#  'hep-th',
#  'hep-th',
#  'cond-mat.mtrl-sci',
#  'cond-mat.str-el cond-mat.mtrl-sci',
#  'cond-mat.dis-nn cond-mat.mtrl-sci',
#  'astro-ph',
#  'astro-ph',
#  'math.AG',
#  'cond-mat.mtrl-sci cond-mat.soft',
#  'math.ST stat.TH',
#  'cs.IT math.IT',
#  'math.NT',
#  'math.CO math.AC math.AG',
#  'astro-ph',
#  'cond-mat.soft cond-mat.stat-mech',
#  'cond-mat.str-el cond-mat.mtrl-sci',
#  'cond-mat.mes-hall cond-mat.supr-con',
#  'astro-ph',
#  'nucl-ex',
#  'hep-th',
#  'astro-ph',
#  'physics.soc-ph',
#  'astro-ph',
#  'hep-th hep-ph',
#  'nucl-th',
#  'math.NT',
#  'physics.comp-ph physics.chem-ph',
#  'astro-ph',
#  'math.AG',
#  'hep-ph',
#  'physics.atom-ph physics.gen-ph',
#  'cond-mat.supr-con cond-mat.stat-mech',
#  'physics.optics',
#  'physics.gen-ph',
#  'hep-th math-ph math.MP',
#  'math.AP',
#  'math.AG math.CV',
#  'q-fin.PR math.PR',
#  'cond-mat.other cond-mat.mtrl-sci',
#  'cond-mat.soft',
#  'cond-mat.mes-hall cond-mat.str-el',
#  'hep-ex',
#  'cond-mat.other cond-mat.mtrl-sci',
#  'quant-ph',
#  'astro-ph',
#  'physics.class-ph',
#  'astro-ph',
#  'hep-th',
#  'astro-ph',
#  'astro-ph',
#  'cond-mat.dis-nn cond-mat.stat-mech',
#  'math.RT math.GR',
#  'math.PR math-ph math.MP',
#  'math.OA math.KT',
#  'nucl-th',
#  'cond-mat.mtrl-sci cond-mat.mes-hall',
#  'astro-ph',
#  'cond-mat.soft cond-mat.stat-mech',
#  'math.PR math.ST stat.TH',
#  'q-fin.GN physics.soc-ph q-fin.ST',
#  'cs.IT math.IT',
#  'cond-mat.str-el',
#  'cond-mat.other',
#  'cond-mat.other physics.optics quant-ph',
#  'hep-ex',
#  'math.DG gr-qc hep-th math-ph math.AP math.MP',
#  'math.DG',
#  'hep-ex',
#  'physics.gen-ph q-bio.PE',
#  'cond-mat.supr-con cond-mat.str-el',
#  'math.CO math.DS',
#  'hep-ph hep-ex',
#  'hep-ph hep-lat hep-th nucl-th',
#  'astro-ph',
#  'cond-mat.str-el',
#  'hep-ph hep-ex',
#  'quant-ph',
#  'cond-mat.mes-hall cond-mat.mtrl-sci',
#  'math.AC math.AG',
#  'quant-ph',
#  'physics.optics cond-mat.soft nlin.PS physics.flu-dyn',
#  'physics.comp-ph physics.data-an',
#  'hep-ph nucl-th',
#  'cond-mat.str-el cond-mat.dis-nn',
#  'math.CV math.SP',
#  'q-bio.PE',
#  'astro-ph',
#  'astro-ph',
#  'math.AG',
#  'hep-ph',
#  'astro-ph',
#  'math.CV math.AC',
#  'math.AG',
#  'cond-mat.soft',
#  'cond-mat.mtrl-sci',
#  'hep-ph',
#  'astro-ph',
#  'hep-ph nucl-th',
#  'gr-qc',
#  'hep-ex hep-lat hep-ph',
#  'hep-ex',
#  'hep-th quant-ph',
#  'astro-ph',
#  'cond-mat.supr-con cond-mat.str-el',
#  'q-bio.BM q-bio.QM',
#  'astro-ph',
#  'cond-mat.mes-hall cond-mat.mtrl-sci',
#  'astro-ph',
#  'hep-ex',
#  'quant-ph',
#  'math.CO',
#  'quant-ph',
#  'hep-ph nucl-th',
#  'astro-ph',
#  'math.CO',
#  'astro-ph',
#  'gr-qc astro-ph hep-th',
#  'hep-th astro-ph gr-qc hep-ph',
#  'q-bio.NC',
#  'math.RA math.RT',
#  'cond-mat.mes-hall cond-mat.str-el',
#  'cond-mat.mtrl-sci cond-mat.mes-hall',
#  'astro-ph',
#  'cond-mat.other',
#  'astro-ph',
#  'astro-ph',
#  'math.OC math.CA',
#  'astro-ph',
#  'cond-mat.mes-hall cond-mat.str-el',
#  'astro-ph',
#  'cond-mat.mtrl-sci cond-mat.str-el',
#  'math.AG',
#  'math.NT math.RT',
#  'quant-ph',
#  'q-fin.ST physics.data-an physics.soc-ph',
#  'math.AP math-ph math.MP',
#  'hep-th astro-ph gr-qc',
#  'math.OA',
#  'hep-ph',
#  'math-ph math.MP',
#  'nucl-ex',
#  'cs.IT cs.LG math.IT',
#  'hep-th',
#  'cond-mat.stat-mech q-bio.NC',
#  'astro-ph',
#  'astro-ph',
#  'astro-ph',
#  'astro-ph',
#  'quant-ph',
#  'math.AG math.CA',
#  'astro-ph gr-qc hep-th',
#  'cond-mat.soft cond-mat.stat-mech physics.ins-det physics.optics',
#  'astro-ph',
#  'cond-mat.str-el',
#  'cond-mat.dis-nn cond-mat.stat-mech',
#  'math.CO',
#  'physics.soc-ph',
#  'math.AP math-ph math.MP',
#  'math.PR cond-mat.stat-mech math-ph math.CO math.MP',
#  'astro-ph',
#  'hep-th',
#  'physics.soc-ph',
#  'cond-mat.supr-con cond-mat.str-el',
#  'cond-mat.mes-hall',
#  'cond-mat.supr-con cond-mat.dis-nn',
#  'hep-ph physics.atom-ph',
#  'cond-mat.mtrl-sci',
#  'hep-ph',
#  'math.DS math-ph math.MP',
#  'physics.chem-ph',
#  'physics.chem-ph',
#  'physics.optics',
#  'cond-mat.mes-hall',
#  'physics.optics',
#  'math.PR math.AP',
#  'nucl-th',
#  'astro-ph',
#  'cond-mat.soft',
#  'math.OC',
#  'quant-ph',
#  'nucl-ex',
#  'nucl-th',
#  'physics.atom-ph',
#  'cond-mat.stat-mech cond-mat.other',
#  'math.DG math.GT',
#  'cond-mat.str-el',
#  'math-ph math.MP',
#  'cond-mat.str-el cond-mat.supr-con',
#  'astro-ph',
#  'gr-qc astro-ph',
#  'math.NA math.DS',
#  'astro-ph',
#  'hep-lat hep-ph hep-th',
#  'cond-mat.mes-hall',
#  'cond-mat.mes-hall',
#  'physics.optics physics.class-ph',
#  'physics.data-an',
#  'cond-mat.supr-con',
#  'cond-mat.mes-hall cond-mat.str-el',
#  'hep-th',
#  'cs.PF cs.NI',
#  'nucl-th',
#  'hep-th',
#  'cond-mat.other nlin.PS',
#  'astro-ph',
#  'astro-ph',
#  'math.NT math-ph math.MP',
#  'hep-th',
#  'cond-mat.stat-mech cond-mat.dis-nn',
#  'math.ST math.PR stat.ME stat.TH',
#  'astro-ph',
#  'cond-mat.dis-nn cond-mat.mes-hall',
#  'cond-mat.dis-nn cond-mat.mes-hall',
#  'cond-mat.str-el',
#  'stat.ME physics.soc-ph stat.AP',
#  'q-fin.CP math.PR',
#  'cond-mat.mes-hall',
#  'math.DG math.CA',
#  'hep-th hep-ph',
#  'gr-qc',
#  'math.DG math.CA',
#  'math.CV',
#  'hep-th',
#  'gr-qc',
#  'gr-qc',
#  'math.GM',
#  'hep-th astro-ph hep-ph',
#  'quant-ph',
#  'quant-ph',
#  'math.AP',
#  'hep-ex',
#  'cond-mat.stat-mech cond-mat.soft physics.chem-ph',
#  'cond-mat.stat-mech',
#  'quant-ph',
#  'cond-mat.str-el',
#  'cond-mat.supr-con',
#  'quant-ph',
#  'astro-ph',
#  'astro-ph',
#  'cond-mat.other',
#  'astro-ph',
#  'quant-ph',
#  'math.NA',
#  'q-fin.ST cond-mat.other physics.data-an physics.soc-ph',
#  'astro-ph',
#  'math.KT math.RA',
#  'cond-mat.mes-hall',
#  'hep-th',
#  'math.AG math.AC math.RT',
#  'astro-ph',
#  'nucl-ex',
#  'cond-mat.mtrl-sci',
#  'gr-qc',
#  'math.NA',
#  'hep-th',
#  'cond-mat.mtrl-sci',
#  'hep-ph',
#  'math.NA',
#  'cs.DS cs.PF',
#  'astro-ph',
#  'hep-th astro-ph hep-ph',
#  'astro-ph',
#  'astro-ph',
#  'hep-th astro-ph gr-qc',
#  'astro-ph',
#  'hep-lat',
#  'quant-ph astro-ph cond-mat.stat-mech hep-ph math-ph math.MP',
#  'gr-qc',
#  'math.AT',
#  'astro-ph gr-qc',
#  'quant-ph',
#  'math.AP math.GM',
#  'cs.IT math.IT',
#  'quant-ph',
#  'cond-mat.stat-mech cond-mat.other',
#  'cs.IT math.IT',
#  'astro-ph',
#  'nucl-th nucl-ex',
#  'math.CA',
#  'astro-ph',
#  'astro-ph',
#  'astro-ph',
#  'astro-ph',
#  'math-ph math.MP',
#  'quant-ph',
#  'quant-ph',
#  'astro-ph',
#  'math.CO math.RT',
#  'physics.plasm-ph physics.space-ph',
#  'astro-ph',
#  'physics.optics',
#  'cond-mat.str-el',
#  'hep-th',
#  'astro-ph',
#  'math.QA',
#  'cond-mat.supr-con cond-mat.str-el',
#  'astro-ph',
#  'astro-ph',
#  'cond-mat.supr-con cond-mat.soft',
#  'hep-th',
#  'cond-mat.mes-hall',
#  'cs.IT math.IT',
#  'astro-ph',
#  'math.AP math.CA',
#  'cs.DS',
#  'astro-ph',
#  'math.CO',
#  'hep-th',
#  'cs.IT math.IT',
#  'math.AG math.CO math.GT math.SG',
#  'hep-ph',
#  'hep-th',
#  'cond-mat.other',
#  'cond-mat.str-el',
#  'astro-ph hep-ph nucl-th',
#  'cond-mat.supr-con',
#  'math.RA math.QA',
#  'physics.atm-clus',
#  'cond-mat.dis-nn cond-mat.stat-mech math-ph math.MP',
#  'gr-qc',
#  'cond-mat.stat-mech',
#  'math.CO',
#  'nucl-ex',
#  'math.DG',
#  'physics.optics',
#  'physics.atom-ph',
#  'physics.atom-ph physics.class-ph',
#  'astro-ph gr-qc hep-ph',
#  'cs.CR',
#  'math.CA',
#  'cs.PF',
#  'cs.PF cs.CR',
#  'astro-ph',
#  'astro-ph',
#  'astro-ph',
#  'cs.PF cs.SE',
#  'math.CV math.DG',
#  'cond-mat.other',
#  'cond-mat.mes-hall',
#  'cond-mat.stat-mech math-ph math.MP',
#  'physics.acc-ph',
#  'astro-ph',
#  'math.SP',
#  'astro-ph',
#  'math.AG',
#  'math.GM',
#  'math.PR',
#  'astro-ph',
#  'cond-mat.mtrl-sci',
#  'cs.PF',
#  'cond-mat.stat-mech',
#  'astro-ph',
#  'astro-ph',
#  'hep-ph',
#  'math.CV',
#  'math.FA math.GN',
#  'cond-mat.str-el',
#  'physics.data-an physics.gen-ph',
#  'cond-mat.str-el',
#  'physics.data-an physics.soc-ph',
#  'astro-ph',
#  'nucl-ex',
#  'nlin.CD',
#  'quant-ph',
#  'astro-ph',
#  'math.AG math.CO',
#  'cond-mat.dis-nn cond-mat.stat-mech',
#  'math.CV',
#  'hep-th',
#  'astro-ph',
#  'cond-mat.supr-con cond-mat.mes-hall',
#  'cond-mat.dis-nn cond-mat.stat-mech',
#  'cond-mat.str-el',
#  'physics.gen-ph',
#  'astro-ph',
#  'astro-ph',
#  'math.PR math.ST stat.CO stat.TH',
#  'cond-mat.mes-hall',
#  'astro-ph',
#  'math.GT math.DG',
#  'math.OA math.FA',
#  'astro-ph',
#  'physics.atom-ph',
#  'cond-mat.stat-mech cond-mat.mtrl-sci',
#  'math.AP math-ph math.MP physics.optics',
#  'cond-mat.mtrl-sci',
#  'nucl-ex',
#  'astro-ph',
#  'math.AG math.ST stat.TH',
#  'cond-mat.mes-hall',
#  'nucl-th',
#  'hep-th gr-qc hep-ph math-ph math.MP math.QA',
#  'math.CA',
#  'math.ST stat.TH',
#  'math.NT',
#  'cond-mat.other cond-mat.soft cond-mat.stat-mech',
#  'math.OC',
#  'math.NT',
#  'hep-ph astro-ph hep-th',
#  'hep-th gr-qc hep-ph',
#  'hep-th',
#  'astro-ph',
#  'astro-ph',
#  'cond-mat.str-el',
#  'nucl-th',
#  'cond-mat.mtrl-sci',
#  'hep-th',
#  'math-ph math.MP math.RT',
#  'cond-mat.stat-mech cond-mat.other',
#  'astro-ph',
#  'hep-th cond-mat.str-el math-ph math.MP',
#  'astro-ph',
#  'math.DS',
#  'gr-qc',
#  'astro-ph',
#  'math.PR math.ST stat.TH',
#  'astro-ph',
#  'astro-ph',
#  'astro-ph',
#  'math.OC',
#  'astro-ph',
#  'cond-mat.dis-nn cond-mat.str-el quant-ph',
#  'astro-ph',
#  'astro-ph',
#  'cs.IT cs.LG math.IT',
#  'hep-th gr-qc',
#  'cond-mat.supr-con',
#  'math.PR',
#  'astro-ph',
#  'hep-ph',
#  'quant-ph',
#  'astro-ph',
#  'physics.hist-ph',
#  'physics.hist-ph astro-ph',
#  'quant-ph',
#  'quant-ph',
#  'nucl-ex',
#  'cs.IT cs.AR math.IT',
#  'astro-ph',
#  'quant-ph',
#  'astro-ph',
#  'hep-ph hep-ex',
#  'cond-mat.stat-mech',
#  'astro-ph',
#  'cond-mat.stat-mech cond-mat.mtrl-sci',
#  'cond-mat.stat-mech cond-mat.mtrl-sci',
#  'cond-mat.stat-mech cond-mat.dis-nn nlin.CD',
#  'cond-mat.mes-hall',
#  'astro-ph',
#  'astro-ph',
#  'cond-mat.mes-hall',
#  'math.DG',
#  'physics.gen-ph',
#  'hep-ph',
#  'quant-ph',
#  'cs.NE cs.AI',
#  'gr-qc',
#  'hep-ph',
#  'astro-ph',
#  'math.GR',
#  'cond-mat.mtrl-sci',
#  'math.OC',
#  'gr-qc',
#  'gr-qc hep-th math.AP',
#  'math.CO',
#  'hep-ph hep-th',
#  'hep-th',
#  'math.CV',
#  'math.NT',
#  'math.RT',
#  'hep-ex',
#  ...]

# %%
## let's look at the distribution of the categories and maybe look for a more human readable version of the categories: https://arxiv.org/category_taxonomy
categories = data['train']['categories']
# split by space and flatten
categories_listed = [cat.split(' ') for cat in categories]
categories_primary_listed = [cat[0] for cat in categories_listed]
categories_secondary_listed = [cat[1] for cat in categories_listed if len(cat) > 1]
categories_secondary_anylisted = [cat[-1] for cat in categories_listed]
categories_secondary_anylisted_na = [cat[-1] if len(cat) > 1 else '' for cat in categories_listed]
unique_categories = sorted(set([item for sublist in categories_listed for item in sublist]))

print(f"Label cardinality: {np.mean([len(cat) for cat in categories_listed])}") #1.5 labels per abstract

#validity check on each category

unique_categories, len(unique_categories) # 176 unique categories

#plotly bar chart
fig = go.Figure(data=[go.Bar(x=unique_categories, y=[categories_primary_listed.count(cat) for cat in unique_categories])])
fig.update_layout(title_text='(1.1) Distribution of primary categories')
fig.show()
fig = go.Figure(data=[go.Bar(x=unique_categories, y=[categories_secondary_listed.count(cat) for cat in unique_categories])])
fig.update_layout(title_text='(1.2) Distribution of secondary categories')
fig.show()
# Out:
# Label cardinality: 1.6957565665834098

# %%
# distribution of primary and secondary categories
fig = go.Figure(data=[go.Bar(x=unique_categories, y=[categories_primary_listed.count(cat) for cat in unique_categories], name='primary'),
                      go.Bar(x=unique_categories, y=[categories_secondary_listed.count(cat) for cat in unique_categories], name='secondary')])
fig.update_layout(title_text='(1.3) Distribution of primary and secondary categories')
fig.show()

# %%
## correlation between primary and secondary categories

df = pd.DataFrame({'primary': categories_primary_listed, 'secondary': categories_secondary_anylisted})
df['primary'] = df['primary'].astype('category')
df['secondary'] = df['secondary'].astype('category')
df['primary'] = df['primary'].cat.codes
df['secondary'] = df['secondary'].cat.codes
print(df)
categories_corr = df.corr()
# fig = go.Figure(data=go.Heatmap(z=categories_corr, x=unique_categories, y=unique_categories))
# fig.update_layout(title_text='(1.3) Correlation between primary categories')
# fig.show()
# Out:
#          primary  secondary
# 0             79         69
# 1             87         24
# 2            133        123
# 3             87         76
# 4             86         81
# ...          ...        ...
# 2399797      171         19
# 2399798      171         19
# 2399799      171         19
# 2399800      171         19
# 2399801      171         19
#
# [2399802 rows x 2 columns]

# %%
## correlation between primary and secondary categories
# create a dataframe with the categories as columns

unique_categories_na = unique_categories + ['']
categories_df = pd.DataFrame(columns=unique_categories_na).fillna(0)
categories_df[''] = [0 for _ in range(len(categories_listed))]
categories_df.fillna(0,inplace=True)
for i in tqdm(range(len(categories_listed))):
    secondary = categories_secondary_anylisted_na[i]
    secondary_index = unique_categories_na.index(secondary)
    categories_df.iat[i, secondary_index] = 1
    #categories_df.loc[i] = #[cat in categories_listed[i] for cat in unique_categories]
categories_df = categories_df.astype(int)
categories_corr = categories_df.corr()
print(categories_corr)
# fig = go.Figure(data=go.Heatmap(z=categories_corr, x=unique_categories, y=unique_categories))
# fig.update_layout(title_text='(1.3) Correlation between primary categories')
# fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-97c5504d3970> in <module>
#       6 #categories_df.loc[0] = [cat in categories_listed[i] for i, cat in enumerate(unique_categories_na)]
#       7 categories_df[''] = [0 for _ in range(len(categories_listed))]
# ----> 8 categories_df.fillna(0,inplace=True)
#       9 for i in tqdm(range(len(categories_listed))):
#      10     secondary = categories_secondary_anylisted_na[i]
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    4460         downcast=None,
#    4461     ) -> Optional[DataFrame]:
# -> 4462         return super().fillna(
#    4463             value=value,
#    4464             method=method,
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6427
#    6428             elif not is_list_like(value):
# -> 6429                 new_data = self._mgr.fillna(
#    6430                     value=value, limit=limit, inplace=inplace, downcast=downcast
#    6431                 )
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/internals/managers.py in fillna(self, value, limit, inplace, downcast)
#     619
#     620     def fillna(self, value, limit, inplace: bool, downcast) -> "BlockManager":
# --> 621         return self.apply(
#     622             "fillna", value=value, limit=limit, inplace=inplace, downcast=downcast
#     623         )
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast)
#     443             nb._putmask_simple(mask, value)
#     444             # TODO: should be nb._maybe_downcast?
# --> 445             return self._maybe_downcast([nb], downcast)
#     446
#     447         # we can't process the value, but nothing to do
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/internals/blocks.py in _maybe_downcast(self, blocks, downcast)
#    2598
#    2599         # split and convert the blocks
# -> 2600         return extend_blocks([b.convert(datetime=True, numeric=False) for b in blocks])
#    2601
#    2602     def _can_hold_element(self, element: Any) -> bool:
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/internals/blocks.py in <listcomp>(.0)
#    2598
#    2599         # split and convert the blocks
# -> 2600         return extend_blocks([b.convert(datetime=True, numeric=False) for b in blocks])
#    2601
#    2602     def _can_hold_element(self, element: Any) -> bool:
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/internals/blocks.py in convert(self, copy, datetime, numeric, timedelta)
#    2585
#    2586         if self.ndim == 2:
# -> 2587             blocks = self.split_and_operate(None, f, False)
#    2588         else:
#    2589             values = f(None, self.values.ravel(), None)
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/internals/blocks.py in split_and_operate(self, mask, f, inplace, ignore_failures)
#     531                 #  reduction that is dropping nuisance columns GH#37827
#     532                 try:
# --> 533                     nv = f(m, v, i)
#     534                 except TypeError:
#     535                     if ignore_failures:
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/internals/blocks.py in f(mask, val, idx)
#    2571         def f(mask, val, idx):
#    2572             shape = val.shape
# -> 2573             values = soft_convert_objects(
#    2574                 val.ravel(),
#    2575                 datetime=datetime,
#
# ~/.virtualenvs/SOTA/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in soft_convert_objects(values, datetime, numeric, timedelta, copy)
#    1137         # bound of nanosecond-resolution 64-bit integers.
#    1138         try:
# -> 1139             values = lib.maybe_convert_objects(values, convert_datetime=True)
#    1140         except (OutOfBoundsDatetime, ValueError):
#    1141             pass
#
# KeyboardInterrupt:

# %%
import numpy as np
# Create a numpy array to store the correlation values
categories_corr = np.zeros((len(unique_categories_na), len(unique_categories_na)))

# Iterate over the categories_listed and update the correlation matrix
for i in tqdm(range(len(categories_listed))):
    primary = categories_primary_listed[i]
    primary_index = unique_categories_na.index(primary)
    secondary = categories_secondary_anylisted_na[i]
    secondary_index = unique_categories_na.index(secondary)
    categories_corr[primary_index, secondary_index] += 1

# Calculate the correlation matrix
categories_corr = np.corrcoef(categories_corr.T)
categories_corr
fig = go.Figure(data=go.Heatmap(z=categories_corr, x=unique_categories, y=unique_categories))
fig.update_layout(title_text='(1.4) Correlation between primary and secondary categories')
fig.show()
# Out:
# 100%|██████████| 2399802/2399802 [00:06<00:00, 399332.29it/s]
# /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages/numpy/lib/function_base.py:2691: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /home/jordy/.virtualenvs/SOTA/lib/python3.8/site-packages/numpy/lib/function_base.py:2692: RuntimeWarning:
#
# invalid value encountered in true_divide

# %%
fields= sorted(set([cat.split(".")[0] for cat in unique_categories]))
fields, len(fields)
#print([cat for cat in unique_categories if categories_primary_listed.count(cat) > 10000]) # 10 categories with more than 10k papers
# Out:
# (['acc-phys',
#   'adap-org',
#   'alg-geom',
#   'ao-sci',
#   'astro-ph',
#   'atom-ph',
#   'bayes-an',
#   'chao-dyn',
#   'chem-ph',
#   'cmp-lg',
#   'comp-gas',
#   'cond-mat',
#   'cs',
#   'dg-ga',
#   'econ',
#   'eess',
#   'funct-an',
#   'gr-qc',
#   'hep-ex',
#   'hep-lat',
#   'hep-ph',
#   'hep-th',
#   'math',
#   'math-ph',
#   'mtrl-th',
#   'nlin',
#   'nucl-ex',
#   'nucl-th',
#   'patt-sol',
#   'physics',
#   'plasm-ph',
#   'q-alg',
#   'q-bio',
#   'q-fin',
#   'quant-ph',
#   'solv-int',
#   'stat',
#   'supr-con'],
#  38)

# %%
underspecified_categories = sorted(set([cat for cat in unique_categories if len(cat.split(".")) == 1])) #underspecified category?
underspecified_categories, len(underspecified_categories), {k:categories_primary_listed.count(k) for k in underspecified_categories} #30 underspecified categories that have no subcategories
# Out:
# (['acc-phys',
#   'adap-org',
#   'alg-geom',
#   'ao-sci',
#   'astro-ph',
#   'atom-ph',
#   'bayes-an',
#   'chao-dyn',
#   'chem-ph',
#   'cmp-lg',
#   'comp-gas',
#   'cond-mat',
#   'dg-ga',
#   'funct-an',
#   'gr-qc',
#   'hep-ex',
#   'hep-lat',
#   'hep-ph',
#   'hep-th',
#   'math-ph',
#   'mtrl-th',
#   'nucl-ex',
#   'nucl-th',
#   'patt-sol',
#   'plasm-ph',
#   'q-alg',
#   'q-bio',
#   'quant-ph',
#   'solv-int',
#   'supr-con'],
#  30,
#  {'acc-phys': 46,
#   'adap-org': 306,
#   'alg-geom': 1209,
#   'ao-sci': 13,
#   'astro-ph': 94246,
#   'atom-ph': 68,
#   'bayes-an': 11,
#   'chao-dyn': 1770,
#   'chem-ph': 129,
#   'cmp-lg': 894,
#   'comp-gas': 140,
#   'cond-mat': 11357,
#   'dg-ga': 562,
#   'funct-an': 320,
#   'gr-qc': 61387,
#   'hep-ex': 22487,
#   'hep-lat': 17667,
#   'hep-ph': 129686,
#   'hep-th': 103319,
#   'math-ph': 30958,
#   'mtrl-th': 165,
#   'nucl-ex': 11369,
#   'nucl-th': 32661,
#   'patt-sol': 452,
#   'plasm-ph': 28,
#   'q-alg': 1177,
#   'q-bio': 0,
#   'quant-ph': 104101,
#   'solv-int': 844,
#   'supr-con': 69})

# %%
## reuse code from https://www.kaggle.com/code/lucafuligni/exploratory-data-analysis-arxiv-dataset#Categories to obtain a more human readable version of the categories
## alternate: https://www.kaggle.com/code/matthewmaddock/nlp-arxiv-dataset-transformers-and-umap 
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://arxiv.org/category_taxonomy"

# Send a GET request to the URL
response = requests.get(url)

# Get the page source from the response content
page_source = response.text

# Parse the page source
soup = BeautifulSoup(page_source, 'html.parser')

# Find the category list element
category_list = soup.find(id='category_taxonomy_list')

# Extract the category information
categories = []
main_category = None
for category in category_list.find_all('h4'):
    if category.find_previous('h2'):
        main_category = category.find_previous('h2').text
    category_id = category.text.split(' (')[0]  # Switched with 'category_name'
    category_name = category.text.split('(')[1].split(')')[0]  # Switched with 'category_id'
    category_description = category.find_next('p').text
    categories.append({
        "ID": category_id,  # Switched with 'category_name'
        "Main Category": main_category,
        "Name": category_name,  # Switched with 'category_id'
        "Description": category_description
    })


# Create a dataframe from the categories list
categories_df = pd.DataFrame(categories)
categories_df
# Out:
#           ID     Main Category  \
# 0      cs.AI  Computer Science
# 1      cs.AR  Computer Science
# 2      cs.CC  Computer Science
# 3      cs.CE  Computer Science
# 4      cs.CG  Computer Science
# ..       ...               ...
# 150  stat.CO        Statistics
# 151  stat.ME        Statistics
# 152  stat.ML        Statistics
# 153  stat.OT        Statistics
# 154  stat.TH        Statistics
#
#                                                 Name  \
# 0                            Artificial Intelligence
# 1                              Hardware Architecture
# 2                           Computational Complexity
# 3    Computational Engineering, Finance, and Science
# 4                             Computational Geometry
# ..                                               ...
# 150                                      Computation
# 151                                      Methodology
# 152                                 Machine Learning
# 153                                 Other Statistics
# 154                                Statistics Theory
#
#                                            Description
# 0    Covers all areas of AI except Vision, Robotics...
# 1    Covers systems organization and hardware archi...
# 2    Covers models of computation, complexity class...
# 3    Covers applications of computer science to the...
# 4    Roughly includes material in ACM Subject Class...
# ..                                                 ...
# 150              Algorithms, Simulation, Visualization
# 151  Design, Surveys, Model Selection, Multiple Tes...
# 152  Covers machine learning papers (supervised, un...
# 153  Work in statistics that does not fit into the ...
# 154  stat.TH is an alias for math.ST. Asymptotics, ...
#
# [155 rows x 4 columns]

# %%
categories_df['ID'].nunique(), categories_df['Name'].nunique(), len(unique_categories)

superfluous = [cat for cat in unique_categories if cat not in categories_df['ID'].values]
superfluous, len(superfluous) # 0 superfluous categories
for cat in superfluous:
    print(f"{cat}: 1:{categories_primary_listed.count(cat)} 2:{categories_secondary_listed.count(cat)}")
  ## - some are very infrequent, e.g. 'q-bio' (Quantitative Biology) with 0 primary Category counts

## lets look at the long tail of categories to see if we can remove some categories
long_tail_primary, long_tail_any = [], []
for cat in unique_categories:
    primary_count = categories_primary_listed.count(cat)
    secondary_count = categories_secondary_listed.count(cat)
    any_count = primary_count + secondary_count
    if primary_count < 50:
        long_tail_primary.append(cat)
    if any_count < 100:
        long_tail_any.append(cat)
long_tail_primary, long_tail_any, len(long_tail_primary), len(long_tail_any) # 33 primary categories with less than 50 papers, 84 categories with less than 100 papers
CATEGORIES_TO_REMOVE = set(long_tail_primary + long_tail_any)
# Out:
# acc-phys: 1:46 2:3
# adap-org: 1:306 2:278
# alg-geom: 1:1209 2:214
# ao-sci: 1:13 2:4
# astro-ph: 1:94246 2:11120
# atom-ph: 1:68 2:54
# bayes-an: 1:11 2:2
# chao-dyn: 1:1770 2:586
# chem-ph: 1:129 2:111
# cmp-lg: 1:894 2:0
# comp-gas: 1:140 2:64
# cond-mat: 1:11357 2:2665
# dg-ga: 1:562 2:144
# funct-an: 1:320 2:75
# mtrl-th: 1:165 2:56
# patt-sol: 1:452 2:0
# plasm-ph: 1:28 2:3
# q-alg: 1:1177 2:1
# q-bio: 1:0 2:701
# solv-int: 1:844 2:0
# supr-con: 1:69 2:87

# %%
## manual lookup of missing categories
category_mapping = {
    'acc-phys': 'Accelerator Physics',
  'adap-org': 'Adaptation, Noise, and Self-Organizing Systems',
  'alg-geom': 'Algebraic Geometry',
  'ao-sci': 'Atmospheric and Oceanic Physics',
  'astro-ph': 'Astrophysics',
  'atom-ph': 'Atomic Physics',
  'bayes-an': 'Bayesian Analysis',
  'chao-dyn': 'Chaotic Dynamics',
  'chem-ph': 'Chemical Physics',
  'cmp-lg'  : 'Computation and Language',
  'comp-gas'    : 'Cellular Automata and Lattice Gases',
  'cond-mat': 'Condensed Matter',
  'dg-ga': 'Differential Geometry',
  'funct-an': 'Functional Analysis',
  'mtrl-th': 'Materials Science',
  'patt-sol': 'Pattern Formation and Solitons',
  'plasm-ph': 'Plasma Physics',
  'q-alg': 'Quantum Algebra',
  'q-bio': 'Quantitative Biology',
  'solv-int': 'Exactly Solvable and Integrable Systems',
  'supr-con': 'Superconductivity',
}

for cat in category_mapping:
    categories_df = categories_df.append({'ID': cat, 'Main Category': '', 'Name': category_mapping[cat], 'Description': ''}, ignore_index=True)
categories_df.to_csv('/home/jordy/code/opensource/IRIS/AAPD/data/arxiv_categories.csv', index=False)

# %% [markdown]
# ### My understanding of the categories
#
# Fields: (38)
#
# Fields of study/Categories: (176) - at most chained 2 levels deep, e.g., *acc-phys or CS.AI*
#
# Open questions:
# - What is the label cardinality on average and is this different per field?
# - How correlated are the primary and secondary categories?
# - How many papers are in more than one category?
# - Is there any label imputation needed?
# - Can we translate categories to human readable labels (potentially including the instruction/description) for use in zero-shot classification (e.g., setfit?)?
#
# Beware that there might be label noise in the dataset from category misuse or mislabeling. (https://blog.arxiv.org/2019/12/05/arxiv-machine-learning-classification-guide/)

# %%
#### let's make a subset with 50 papers per primary category for EDA purposes
K_per_category = 50
cat_indices = []
for cat in unique_categories:
    indices = []
    for i, x in enumerate(categories_listed): 
        if x[0] == cat:
            indices.append(i)
            if len(indices) == K_per_category:
                break
    cat_indices.extend(indices)

subset = data['train'].select(cat_indices)

# %%
# Q: is the language always English?  --> yes in 99.9% of the cases
from langdetect import detect
from langdetect import DetectorFactory
from collections import Counter
from tqdm import tqdm
DetectorFactory.seed = 0 #for reproducibility
languages = [detect(abstract) for abstract in tqdm(subset['abstract'])]
languages_set = Counter(languages)
languages_set #only English?
# Out:
# 100%|██████████| 16835/16835 [01:12<00:00, 231.53it/s]
# Counter({'en': 16821, 'de': 2, 'et': 1, 'fr': 8, 'it': 1, 'es': 1, 'da': 1})

# %%
## let's look at the length of the abstracts to see if they will fit in Transformer models
abstract_lengths = [len(abstract.split()) for abstract in subset['abstract']]
fig = go.Figure(data=[go.Histogram(x=abstract_lengths, nbinsx=100)])
fig.update_layout(title_text='(2.1) Distribution of abstract lengths')
fig.show()
print([abstract for abstract in subset['abstract'] if len(abstract.split()) < 14]) #short abstracts - withdrawn or plagiarized

# %%
print([abstract for abstract in subset['abstract'] if len(abstract.split()) < 14]) #short abstracts
#len(data['train']['title']), len(np.unique(data['train']['title'])) #2349354 --> duplicate titles
# Out:
# ['  (Makes a Gamma-acylic coherent resolution of a coherent sheaf on a projection\nscheme.)\n', '  (Generalizes theorem of Atiyah and Mumford.)\n', '  We study limiting lines on degenerations of generic hypersurfaces in $P^n$.\n', '  This is a revised version of the paper submitted before.\n', '  This paper has been withdrawn by the authors.\n', '  A selfcontained proof of the KAM theorem in the Thirring model is discussed.\n', '  We comment on a recent article by Hao and Scheraga.\n', '  See chem-ph/9505003.\n', '  The paper was withdrawn by the authors\n', '  paper withdrawn due to the possible error in numerical eigenfunction\ncalculation\n', '  This paper visualizes a knot reduction algorithm\n', '  This paper has been withdrawn.\n', '  Description of a polynomial time reduction of SAT to 2-SAT of polynomial\nsize.\n', '  Major mistakes do not read\n', '  This paper has been withdrawn\n', '  This paper has been withdrawn\n', '  This paper has been withdrawn\n', '  We describe and provide code and examples for a polygonal edge matching\nmethod.\n', '  This paper has been withdrawn by the author ali pourmohammad.\n', '  This paper has been withdrawn by the author ali pourmohammad.\n', '  Mining for trees in a graph is shown to be NP-complete.\n', '  We show the Graceful Tree Conjecture holds.\n', '  Reducing the NP-problems to the convex/linear analysis on the Birkhoff\npolytope.\n', '  Erroneous submission in violation of copyright removed by arXiv admin.\n', '  How to manage knowledge on the Web.\n', '  This a biographical essay about Edsger Wybe Dijkstra.\n', '  Removed by arXiv administration. This article was plagiarised from\nhttp://www.dmi.unict.it/~battiato/download/NSIP_2003_VQ.pdf and other\nlocations.\n', '  Please see the content of this report.\n', '  This paper has been withdrawn.\n', '  This note argues about the validity of web-graph data used in the literature.\n', "  New methods are being employed to meet the Navy's changing\nsoftware-development environment.\n", '  Documents early computer art in the Soviet bloc and describes Marxist art\ntheory.\n', '  This paper has been withdrawn by the author.\n', '  A novel valveless micro impedance pump is proposed and analyzed in this\nstudy.\n', '  This paper has been withdrawn by the author.\n', '  This paper has been withdrawn by the author ali pourmohammad.\n', '  For the most up-to-date version please visit\nhttp://www.cis.upenn.edu/~brautbar/ccgame.pdf\n', '  This paper has been withdrawn by the authors\n', '  Some groups of real analytic diffeomorphism act n-transitively for each\nfinite n.\n', '  I use harmonic maps and minimal surfaces to study quadratic equations in\ngroups.\n', '  Retracted temporarily to fix some erratic things.\n', '  We answer a question raised by V.G.Pestov in the affirmative.\n', '  An unified model of the Universe, Black Holes, particles .... and beyond.\n', '  We report on most recent Charm and Charmonium spectroscopy results from the\nB-factories\n', "  Comment on ``Chiral Suppression of Scalar Glueball Decay''\n", '  The proof of proposition 3.6 is not correct\n', '  A remark on a paper by Birkar-Cascini-Hacon-McKernan.\n', '  A simple application of the semipositivity.\n', '  This paper is painfully withdrawn.\n', "  We prove a variation of Gronwall's lemma.\n", '  We introduce Rota-Baxter categories and construct examples of such\nstructures.\n', '  Withdrawn by author - Superseded by arXiv:0910.5106 [math.FA].\n', '  This paper has been withdrawn by the author.\n', '  The new property of minimal surfaces is obtained in this article.\n', '  This paper has been withdrawn by the author for further modification.\n', '  We describe the geometric and dynamical properties of expansive Markov\nsystems.\n', '  Another approach to constructing an upper bound for the Riemann-Farey sum is\ndescribed.\n', '  A few remarks on how mathematics quests for freedom.\n', '  Actual infinity in its various forms is discussed, searched and not found ...

# %%
### sentence encoder to embed every abstract, take averages and plot per primary category

from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-mpnet-base-v2')

## DEV: alternative make scibert into a sentence encoder
# from transformers import AutoTokenizer, AutoModel
# tokenizer = AutoTokenizer.from_pretrained("allenai/scibert_scivocab_uncased")
# model = AutoModel.from_pretrained("allenai/scibert_scivocab_uncased")
# model = SentenceTransformer(model)

#embed every abstract
abstracts = subset['abstract']
abstract_embeddings = model.encode(abstracts, batch_size=32, show_progress_bar=True)
cats = subset['categories']
cats_primary = [cat.split(" ")[0] for cat in cats]
field_primary = [cat.split(".")[0] for cat in cats_primary]

# plot TSNE of the embeddings
from sklearn.manifold import TSNE
import plotly.express as px
tsne = TSNE(n_components=2, random_state=0)
abstracts_tsne = tsne.fit_transform(abstract_embeddings)
abstracts_tsne_df = pd.DataFrame(abstracts_tsne, columns=['tsne1', 'tsne2'])
abstracts_tsne_df['field_primary'] = field_primary
fig = px.scatter(abstracts_tsne_df, x="tsne1", y="tsne2", color="field_primary")
fig.update_layout(title_text='(2.2) TSNE plot of abstract embeddings')
fig.show()
# Out:
# Batches:   0%|          | 0/266 [00:00<?, ?it/s]

# %% [markdown]
# # Preprocessing for training
#
# Now that the EDA is complete, we can define the functions necessary for preprocessing the data for training.
#
# 0. removing all outlier values (duplicates, long-tail noise, etc.)
# 1. keeping primary-secondary categories with at least 10 papers (long-tail categories are not useful for training)
# 2. creating a balanced validation split
# 3. defining a labelset for the model, depending on the type of model we want to train
#    (0. multi-class classification (primary-only using SciBERT))
#    1. zero-shot classification (using the setfit model) --> string labels - human readable/instruction
#    2. multi-label classification (using SciBERT) --> list labels
#    3. generative classification (FlanT5) --> string labels - human readable/instruction

# %%
# conditions: duplicate titles, long-tailed distribution of categories, underspecified categories, language, abstract length

to_field = lambda cat: cat.split(".")[0] #map the categories to the field
to_primary = lambda cat: cat.split(" ")[0] #map the categories to the primary categories
to_secondary = lambda cat: cat.split(" ")[-1] #map the categories to the secondary categories

cat_df = pd.read_csv('../data/arxiv_categories.csv', sep=',') 

def stringlabel_mapping(cat):  #map the categories to the string labels
    cats = cat.split()
    joiner = []
    for cat in cats:
        if cat in cat_df['ID']:
            joiner.append(cat_df[cat_df['ID'] == cat]['Name'].values[0])
    return ' ; '.join(joiner)    

remove_indices = set()
seen = set()
for i, el in enumerate(data['train']):
    if el['title'] in seen:
        remove_indices.add(i)
    else:
        seen.add(el['title'])
    simple_tokenized = el['abstract'].split()
    if len(simple_tokenized) < 14 or len(simple_tokenized) > 350: 
        remove_indices.add(i)
    if any(cat in CATEGORIES_TO_REMOVE for cat in el['categories'].split()):
        remove_indices.add(i)

data['train'] = data['train'].select([i for i in range(len(data['train'])) if i not in remove_indices])

#complex function to apply to the dataset 
def process_categories(x):
    #x['field_primary'] = to_field(x['categories'])
    x['primary'] = to_primary(x['categories'])
    x['secondary'] = to_secondary(x['categories'])
    x['strlabel'] = stringlabel_mapping(x['categories'])
    return x

#keep only relevant columns (id, categories, strlabel, abstract) while doing a map
keep_columns = ['id', 'categories', 'primary', 'secondary', 'strlabel', 'abstract']
data['train'] = data['train'].map(process_categories, batch_size=32, remove_columns=[col for col in data['train'].column_names if col not in keep_columns])
# Out:
# Map:   0%|          | 0/2247644 [00:00<?, ? examples/s]

# %%
## due to the absence of a validation split, let's make our own split, keeping the label distribution as similar as possible
### the below function could be used for more advanced stratification, to also keep the language or length of the abstract balanced over splits
### keeping it simple for now, as we are only interested in the label distribution for the PoC

'''
from skmultilearn.model_selection import IterativeStratification


def iterative_split(df, stratify_columns, splits=(0.25, 0.75)):
    """Custom iterative train test split which
    'maintains balanced representation with respect
    to order-th label combinations.'

    From http://lpis.csd.auth.gr/publications/sechidis-ecmlpkdd-2011.pdf (page 5)
    """
    # One-hot encode the stratify columns and concatenate them
    one_hot_cols = [pd.get_dummies(df[col]) for col in stratify_columns]
    one_hot_cols = pd.concat(one_hot_cols, axis=1).to_numpy()
    stratifier = IterativeStratification(
        n_splits=2, order=len(stratify_columns), sample_distribution_per_fold=list(splits))
    train_indices, test_indices = next(stratifier.split(df.to_numpy(), one_hot_cols))
    # Return the train and test set dataframes
    train, test = df.iloc[train_indices], df.iloc[test_indices]
    return train, test

train, test = iterative_split(split_df, stratify_columns=["primary","secondary"], splits=(0.25, 0.75))
'''
train, validation = train_test_split(data['train'], test_size=0.1, random_state=42, stratify=data['train']['categories']) #10% as we will train stepwise and might not use the whole trainset

#save the splits
train.save_to_disk('/home/jordy/code/opensource/IRIS/AAPD/data/train')
validation.save_to_disk('/home/jordy/code/opensource/IRIS/AAPD/data/validation')
